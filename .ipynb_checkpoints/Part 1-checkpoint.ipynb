# %% [markdown]
# # Load Data

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load
df = pd.read_csv('Data/Crimes_-_2001_to_Present.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369706 entries, 0 to 369705
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    369706 non-null  int64
#  1   Case Number           369706 non-null  object
#  2   Date                  369706 non-null  object
#  3   Block                 369706 non-null  object
#  4   IUCR                  369706 non-null  object
#  5   Primary Type          369706 non-null  object
#  6   Description           369706 non-null  object
#  7   Location Description  367003 non-null  object
#  8   Arrest                369706 non-null  bool
#  9   Domestic              369706 non-null  bool
#  10  Beat                  369706 non-null  int64
#  11  District              369705 non-null  float64
#  12  Ward                  369497 non-null  float64
#  13  Community Area        369497 non-null  float64
#  14  FBI Code              369706 non-null  object
#  15  X Coordinate          359981 non-null  float64
#  16  Y Coordinate          359981 non-null  float64
#  17  Year                  369705 non-null  float64
#  18  Updated On            369705 non-null  object
#  19  Latitude              359980 non-null  float64
#  20  Longitude             359980 non-null  float64
#  21  Location              359980 non-null  object
# dtypes: bool(2), float64(8), int64(2), object(10)
# memory usage: 57.1+ MB
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11037294    JA371270  03/18/2015 12:00:00 PM     0000X W WACKER DR  1153
# 1  11646293    JC213749  12/20/2018 03:00:00 PM  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333  05/01/2016 12:25:00 AM   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511  12/20/2018 04:00:00 PM    045XX N ALBANY AVE  2820
# 4  11645601    JC212935  06/01/2014 12:01:00 AM   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# 0                 BANK   False     False  ...  42.0            32.0        11
# 1            APARTMENT   False     False  ...  36.0            19.0        11
# 2                  NaN   False     False  ...  15.0            63.0        11
# 3            RESIDENCE   False     False  ...  33.0            14.0       08A
# 4            RESIDENCE   False     False  ...  21.0            71.0        11
#
#    X Coordinate Y Coordinate    Year              Updated On  Latitude  \
# 0           NaN          NaN  2015.0  08/01/2017 03:52:26 PM       NaN
# 1           NaN          NaN  2018.0  04/06/2019 04:04:43 PM       NaN
# 2           NaN          NaN  2016.0  04/06/2019 04:04:43 PM       NaN
# 3           NaN          NaN  2018.0  04/06/2019 04:04:43 PM       NaN
# 4           NaN          NaN  2014.0  04/06/2019 04:04:43 PM       NaN
#
#   Longitude  Location
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # Prepare Date Time Index

# %%
# Change 'Date' object to datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Set index
df = df.set_index('Date')
df.index
# Out:
# DatetimeIndex(['2015-03-18 12:00:00', '2018-12-20 15:00:00',
#                '2016-05-01 00:25:00', '2018-12-20 16:00:00',
#                '2014-06-01 00:01:00', '2018-09-01 00:01:00',
#                '2018-01-01 08:00:00', '2018-04-01 00:01:00',
#                '2015-02-02 10:00:00', '2012-05-05 12:25:00',
#                ...
#                '2021-03-26 10:10:00', '2020-12-04 23:30:00',
#                '2021-05-09 09:00:00', '2020-11-18 16:00:00',
#                '2021-04-11 23:05:00', '2021-03-13 02:00:00',
#                '2021-05-13 19:00:00', '2021-05-31 08:12:00',
#                '2020-12-27 09:00:00', '2021-05-01 16:55:00'],
#               dtype='datetime64[ns]', name='Date', length=369706, freq=None)

# %% [markdown]
# # Stakeholder Questions

# %% [markdown]
# ## 1. Comparing Police Districts
# - Which district had the most crimes in 2022?
# - Which had the least?

# %%
# Slice out only data from 2022
year_2022 = df.loc['2022',['District']]
year_2022
# Out:
#                      District
# Date
# 2022-01-11 15:00:00       4.0
# 2022-01-14 15:55:00       7.0
# 2022-08-05 21:00:00       3.0
# 2022-08-14 14:00:00      16.0
# 2022-11-10 03:47:00       7.0
# ...                       ...
# 2022-12-01 00:00:00      11.0
# 2022-08-19 09:00:00      11.0
# 2022-08-22 00:00:00      15.0
# 2022-04-23 12:00:00       4.0
# 2022-12-25 00:00:00      12.0
#
# [3388 rows x 1 columns]

# %%
# Value counts
year_2022_crime_counts = year_2022['District'].value_counts().sort_values()
year_2022_crime_counts
# Out:
# 31.0      1
# 15.0     67
# 20.0     72
# 17.0     94
# 10.0     94
# 22.0    109
# 24.0    109
# 14.0    115
# 5.0     129
# 3.0     131
# 7.0     132
# 4.0     142
# 9.0     144
# 6.0     159
# 2.0     168
# 11.0    178
# 25.0    183
# 18.0    193
# 16.0    211
# 1.0     218
# 12.0    225
# 19.0    233
# 8.0     281
# Name: District, dtype: int64

# %%
# Visualize
fig, ax = plt.subplots(figsize = (12,3))
ax = sns.countplot(data = year_2022, x = 'District', order = year_2022_crime_counts.index)
ax.set(title = '2022 Crimes per Police District', ylabel = '# of Crimes', xlabel = 'Police District');

# %% [markdown]
# - Based on the graph:
#  - Which district had the most crimes in 2022?
#    - District 8
#  - Which had the least
#    - District 31?

# %% [markdown]
# ## 2. Crimes Across the Years:
# - Is the total number of crimes increasing or decreasing across the years?
# - Are there any individual crimes that are doing the opposite (e.g., decreasing when overall crime is increasing or vice-versa)
